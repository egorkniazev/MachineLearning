# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns 

import sklearn

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Выгрузим данные

# %%
boston_dataset = load_boston()
print('boston_dataset_keys = ', boston_dataset.keys())
# Out:
# boston_dataset_keys =  dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# ### Посмотрим на описание данных

# %%
print(boston_dataset.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %% [markdown]
# ### Сформируем датафрейм

# %%
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston['MEDV'] = boston_dataset.target
print("boston.shape = ", boston.shape)
boston.head()
# Out:
# boston.shape =  (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ### Проверим датасет на предмет пропущенных значений

# %%
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ### Нарисуем матрицу корреляций

# %%
correlation_matrix = boston.corr().round(2)
# fig, ax = plt.subplots(figsize=(16,10))      
sns.set(rc={'figure.figsize':(14,14)})
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# ### Посмотрим на распределение целевой метки

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston['MEDV'], bins=30)
plt.show()

# %% [markdown]
# ### Отрисуем зависимости между целевой меткой и наиболее коррелирующими признаками

# %%
plt.figure(figsize=(20, 5))

features = ['LSTAT', 'RM']
target = boston['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = boston[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %% [markdown]
# ### Разделим данные

# %%
X = pd.DataFrame(np.c_[boston['LSTAT'], boston['RM']], columns = ['LSTAT','RM'])
Y = boston['MEDV']

# %% [markdown]
# ### Разделим данные на обучающую и тестовую выборки

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)

# %% [markdown]
# ### Обучим модель линейной регрессии

# %%
lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Посмотрим на результаты

# %%
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))

print("The model performance for training set")
print('RMSE is {}'.format(rmse))

y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

print("The model performance for testing set")
print('RMSE is {}'.format(rmse))
# Out:
# The model performance for training set
# RMSE is 5.6371293350711955
# The model performance for testing set
# RMSE is 5.137400784702912

# %% [markdown]
# ### Рассмотрим распределение ошибки

# %%
errors = (Y_test-y_test_predict).to_numpy()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(errors, bins=30)
plt.show()

# %% [markdown]
# # Задание

# %% [markdown]
# 1) На датасете https://www.kaggle.com/mohansacharya/graduate-admissions построить модель линейной регрессии.
#     Попытаться получить хороший результат на отложенной выборке, не переобучиться, поотбирать фичи, попробовать модели с регуляризацией при необходимости

# %%
df = pd.read_csv('archive/Admission_Predict_Ver1.1.csv')
df['Chance of Admit'] = df['Chance of Admit ']
del df['Chance of Admit ']

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
correlation_matrix = df.corr().round(2)
# fig, ax = plt.subplots(figsize=(16,10))      
sns.set(rc={'figure.figsize':(14,14)})
sns.heatmap(data=correlation_matrix, annot=True)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(df['Chance of Admit'], bins=30)
plt.show()

# %%
plt.figure(figsize=(20, 5))

features = ['GRE Score', 'TOEFL Score', 'CGPA', 
            'University Rating']
target = df['Chance of Admit']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = df[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Chance of Admit')

# %%
X = pd.DataFrame(np.c_[df[features]], columns = features)
Y = df['Chance of Admit']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)

# %%
lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))

print("The model performance for training set")
print('RMSE is {}'.format(rmse))

y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

print("The model performance for testing set")
print('RMSE is {}'.format(rmse))
# Out:
# The model performance for training set
# RMSE is 0.06285591381813185
# The model performance for testing set
# RMSE is 0.05651421031721379

# %%
errors = (Y_test-y_test_predict).to_numpy()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(errors, bins=30)
plt.show()

# %%
lin_model_ridge = sklearn.linear_model.Ridge()
lin_model_ridge.fit(X_train, Y_train)

y_train_predict = lin_model_ridge.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))

print("The model performance for training set")
print('RMSE is {}'.format(rmse))

y_test_predict = lin_model_ridge.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

print("The model performance for testing set")
print('RMSE is {}'.format(rmse))
# Out:
# The model performance for training set
# RMSE is 0.06286608211829939
# The model performance for testing set
# RMSE is 0.05643263856289787

# %%
lin_model_lasso = sklearn.linear_model.Lasso()
lin_model_lasso.fit(X_train, Y_train)

y_train_predict = lin_model_lasso.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))

print("The model performance for training set")
print('RMSE is {}'.format(rmse))

y_test_predict = lin_model_lasso.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

print("The model performance for testing set")
print('RMSE is {}'.format(rmse))
# Out:
# The model performance for training set
# RMSE is 0.12202182920526147
# The model performance for testing set
# RMSE is 0.10691650999514084

# %%
lin_model_lassocv = sklearn.linear_model.LassoCV()
lin_model_lassocv.fit(X_train, Y_train)

y_train_predict = lin_model_lassocv.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))

print("The model performance for training set")
print('RMSE is {}'.format(rmse))

y_test_predict = lin_model_lassocv.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

print("The model performance for testing set")
print('RMSE is {}'.format(rmse))
# Out:
# The model performance for training set
# RMSE is 0.05939831368371964
# The model performance for testing set
# RMSE is 0.05437052471530203

# %%
lin_model_elasticNET = sklearn.linear_model.ElasticNet()
lin_model_elasticNET.fit(X_train, Y_train)

y_train_predict = lin_model_elasticNET.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))

print("The model performance for training set")
print('RMSE is {}'.format(rmse))

y_test_predict = lin_model_elasticNET.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

print("The model performance for testing set")
print('RMSE is {}'.format(rmse))
# Out:
# The model performance for training set
# RMSE is 0.09449838471104222
# The model performance for testing set
# RMSE is 0.08217845109767839
